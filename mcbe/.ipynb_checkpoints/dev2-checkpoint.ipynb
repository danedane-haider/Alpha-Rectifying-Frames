# %%
import numpy as np
import mcbe
from tqdm import tqdm
import matplotlib.pyplot as plt
import scipy

# %%
W= mcbe.get_points("sphere",12,3)

# %%
mcbe.mcbe(W,1000,plot=True)
# Out:
# C:\Users\heckert\Documents\GitHub\Alpha-rectifying-frames\mcbe\mcbe.py:23: RuntimeWarning: invalid value encountered in multiply
#   return z * (z > 0)
# array([ 0.17117051,  0.38867891,  0.20798785, -0.05333793,  0.12204682,
#         0.10311879,  0.09903057,  0.16223853, -0.054225  ,  0.30960516,
#         0.11050295, -0.02095216])
